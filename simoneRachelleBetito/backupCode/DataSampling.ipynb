# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns= None
df1 = pd.read_csv("MetObjects.csv", low_memory=False)

# %%
print(df1)
# Out:
#        Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0         1979.486.1         False             False          1
# 1         1980.264.5         False             False          2
# 2           67.265.9         False             False          3
# 3          67.265.10         False             False          4
# 4          67.265.11         False             False          5
# 5          67.265.12         False             False          6
# 6          67.265.13         False             False          7
# 7          67.265.14         False             False          8
# 8          67.265.15         False             False          9
# 9         1979.486.3         False             False         10
# 10        1979.486.2         False             False         11
# 11        1979.486.7         False             False         12
# 12        1979.486.4         False             False         13
# 13        1979.486.5         False             False         14
# ...

# %%
samples = df1.sample(n=1)
# exclude NaN

# %%
display(samples)
# Out:
#        Object Number  Is Highlight  Is Public Domain  Object ID    Department  \
# 332002   25.10.24.18         False              True     478567  Medieval Art
#
#        Object Name       Title Culture Period Dynasty Reign Portfolio  \
# 332002  Game piece  Game Piece  Coptic    NaN     NaN   NaN       NaN
#
#        Artist Role Artist Prefix Artist Display Name Artist Display Bio  \
# 332002         NaN           NaN                 NaN                NaN
#
#        Artist Suffix Artist Alpha Sort Artist Nationality Artist Begin Date  \
# 332002           NaN               NaN                NaN               NaN
#
#        Artist End Date      Object Date  Object Begin Date  Object End Date  \
# 332002             NaN  4th–7th century                300              699
#
#              Medium                               Dimensions  \
# 332002  Earthenware  Overall: 1/2 x 13/16 in. (1.2 x 2.1 cm)
#
#               Credit Line Geography Type City State        County  \
# ...

# %%
df1.dropna(thresh=2)
# Out:
#        Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0         1979.486.1         False             False          1
# 1         1980.264.5         False             False          2
# 2           67.265.9         False             False          3
# 3          67.265.10         False             False          4
# 4          67.265.11         False             False          5
# 5          67.265.12         False             False          6
# 6          67.265.13         False             False          7
# 7          67.265.14         False             False          8
# 8          67.265.15         False             False          9
# 9         1979.486.3         False             False         10
# 10        1979.486.2         False             False         11
# 11        1979.486.7         False             False         12
# 12        1979.486.4         False             False         13
# 13        1979.486.5         False             False         14
# ...

# %%
df1.isnull().tail()
# Out:
#         Object Number  Is Highlight  Is Public Domain  Object ID  Department  \
# 491794          False         False             False      False       False
# 491795          False         False             False      False       False
# 491796          False         False             False      False       False
# 491797          False         False             False      False       False
# 491798          False         False             False      False       False
#
#         Object Name  Title  Culture  Period  Dynasty  Reign  Portfolio  \
# 491794        False  False     True    True     True   True       True
# 491795        False  False     True    True     True   True       True
# 491796        False  False     True    True     True   True       True
# 491797        False  False     True    True     True   True       True
# 491798        False  False     True    True     True   True       True
#
# ...

# %%
df1.isnull().sum()
# Out:
# Object Number                   0
# Is Highlight                    0
# Is Public Domain                0
# Object ID                       0
# Department                      0
# Object Name                  4393
# Title                       31255
# Culture                    282951
# Period                     402287
# Dynasty                    468515
# Reign                      480594
# Portfolio                  469733
# Artist Role                207531
# Artist Prefix              393620
# Artist Display Name        205441
# Artist Display Bio         254463
# Artist Suffix              479895
# Artist Alpha Sort          205476
# Artist Nationality         298357
# Artist Begin Date          252023
# Artist End Date            254809
# Object Date                 15034
# Object Begin Date               0
# Object End Date                 0
# Medium                       7611
# Dimensions                  76423
# Credit Line                   662
# ...

# %%
df1[df1.Period.isnull()]
# Out:
#        Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0         1979.486.1         False             False          1
# 1         1980.264.5         False             False          2
# 2           67.265.9         False             False          3
# 3          67.265.10         False             False          4
# 4          67.265.11         False             False          5
# 5          67.265.12         False             False          6
# 6          67.265.13         False             False          7
# 7          67.265.14         False             False          8
# 8          67.265.15         False             False          9
# 9         1979.486.3         False             False         10
# 10        1979.486.2         False             False         11
# 11        1979.486.7         False             False         12
# 12        1979.486.4         False             False         13
# 13        1979.486.5         False             False         14
# ...

# %%
df1.shape
# Out:
# (491799, 44)

# %%
df1.dropna(how="any").shape
# Out:
# (0, 44)

# %%
df1.dropna(how="all").shape
# Out:
# (491799, 44)

# %%
newDf = df1.dropna(subset=["Rights and Reproduction", "Country", "Culture", "Title", "Artist Display Name", "City", "Artist Nationality"], how="all").shape
#newDf2 = newDf.dropna(thresh=2)

#newTuple = df1.dropna(subset =["Rights and Reproduction", "Country", "Culture", "Title", "Artist Display Name", "City", "Artist Nationality"], how="all").shape

#newDf = pd.DataFrame(newTuple)
print(newDf)
# Out:
# (491631, 44)

# %%
#sampleDf = newDf.sample(n=5000)

sampleDf = np.random.choice(491631, replace=False, size=5000)

print(sampleDf)
# Out:
# [406099 106931 126504 ... 193662 237693  88480]

# %%
sampleDF.shape

# %%
#https://medium.com/@kasiarachuta/importing-and-exporting-csv-files-in-python-7fa6e4d9f408

dframe.to_csv(“sampled_data.csv”)
# Out:
#   File "<ipython-input-17-ea0ceab95bbc>", line 3
#     dframe.to_csv(“sampled_data.csv”)
#                               ^
# SyntaxError: invalid character in identifier
